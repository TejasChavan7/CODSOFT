# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error

# %%
saledata = pd.read_csv("sales.csv")

# %%
print(saledata.head())
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
print(saledata.shape)
# Out:
# (200, 4)

# %%
print(saledata.describe())
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
sns.pairplot(saledata, x_vars=['TV', 'Radio', 'Newspaper'], y_vars='Sales', kind='scatter')
plt.title('Pairwise Relationships between Features and Sales')
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(saledata[['TV']], saledata[['Sales']], test_size=0.5, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
plt.scatter(X_train, y_train, color='blue', label='Training set')
plt.scatter(X_test, y_test, color='red', label='Testing set')
plt.title('Training and Testing Sets')
plt.xlabel('TV Advertising')
plt.ylabel('Sales')
plt.legend()
plt.show()

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
 predictions = model.predict(X_test)
print(predictions)
# Out:
# [[10.85538585]
#  [ 9.77979849]
#  [12.04301357]
#  [23.20783449]
#  [16.51342355]
#  [10.12712357]
#  [ 7.46616525]
#  [20.4292338 ]
#  [ 8.31206989]
#  [18.04837635]
#  [21.61686152]
#  [11.86374901]
#  [15.75154917]
#  [17.49937863]
#  [11.25873111]
#  [13.71241479]
#  [21.85774827]
#  [ 7.01800385]
#  [11.16349681]
#  [18.93349512]
#  [23.09019212]
#  [14.83842031]
#  [16.78792241]
#  [14.3566468 ]
#  [ 9.9758691 ]
#  [13.8748733 ]
#  [16.25573074]
#  [18.46292565]
#  [19.52730898]
#  [ 8.38489612]
#  [10.77695761]
#  [18.12120258]
#  [22.70365292]
#  [20.51886608]
#  [ 7.71825604]
#  [ 8.026367  ]
#  [10.31759217]
#  [17.10723741]
#  [10.81056971]
#  [ 8.37929411]
#  [ 9.04593419]
#  [ 8.74342524]
#  [14.98407277]
#  [18.72061846]
#  [19.04553547]
#  [12.73206172]
#  [ 7.46056323]
#  [ 7.92553069]
#  [14.02052575]
#  [12.83850005]
#  [13.12980497]
#  [19.83541994]
#  [21.1967102 ]
#  [17.33692013]
#  [ 9.48289156]
#  [10.46884664]
#  [23.38709905]
#  [16.64226995]
# ...

# %%
plt.scatter(X_test, y_test, color='blue', label='Actual Sales')
plt.plot(X_test, predictions, color='red', linewidth=2, label='Predicted Sales')
plt.title('Actual vs Predicted Sales')
plt.xlabel('TV Advertising')
plt.ylabel('Sales')
plt.legend()
plt.show()

# %%
print("Coefficients:", model.coef_)
# Out:
# Coefficients: [[0.05602018]]

# %%
mae = mean_absolute_error(y_test, predictions)
print(f'Mean Absolute Error: {mae}')
# Out:
# Mean Absolute Error: 1.755547673161392

# %%
residuals = y_test - predictions
plt.scatter(X_test, residuals, color='green')
plt.axhline(y=0, color='red', linestyle='--', linewidth=2)
plt.title('Residuals Plot')
plt.xlabel('TV Advertising')
plt.ylabel('Residuals (Actual - Predicted Sales)')
plt.show()
